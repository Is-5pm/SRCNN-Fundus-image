# %%
from google.colab import drive
drive.mount('srcnn')
# Out:
# Mounted at srcnn

# %%
import torch
import matplotlib
import matplotlib.pyplot as plt
import time
import h5py
import srcnn
import torch.optim as optim
import torch.nn as nn
import numpy as np
import math
from torchvision.transforms import ToPILImage
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from torchvision.utils import save_image
from torchvision.transforms.functional import to_pil_image

# %matplotlib inline

import torch.nn as nn
import torch.nn.functional as F
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# 디렉토리 이동
# !cd /content/srcnn/MyDrive/srcnn

# %%
# 입력 이미지 차원 설정하기
input_h, input_w = 99, 99 # sub-image에 대한 크기
out_h, out_w = 99, 99 # label인 high-resolution에 대한 크기

# sub-images와 label 읽어오기
file = h5py.File('/content/srcnn/MyDrive/srcnn/fundus_image_dataset.h5')
in_train = file['data'][:] # train data
out_train = file['label'][:] # train label
file.close()


# float32로 타입 변경
in_train = in_train.astype('float32')
out_train = out_train.astype('float32')

(x_train, x_val, y_train, y_val) = train_test_split(in_train, out_train, test_size=0.25)

# %%
# 커스텀 데이터셋 생성하기
class SRCNNDataset(Dataset):
    def __init__(self, image_data, labels):
        self.image_data = image_data
        self.labels = labels

    def __len__(self):
        return (len(self.image_data))

    def __getitem__(self, index):
        image = self.image_data[index]
        label = self.labels[index]
        return (torch.tensor(image, dtype=torch.float),
            torch.tensor(label, dtype=torch.float))
        
# 데이터셋 생성
train_ds = SRCNNDataset(x_train, y_train)
val_ds = SRCNNDataset(x_val, y_val)

# 데이터로더 생성
train_dl = DataLoader(train_ds, batch_size=128)
val_dl = DataLoader(val_ds, batch_size=128)

# 데이터 체크
#for x, y in train_dl:
#    print(x.shape, y.shape)
#    break

# %%
#모델 구축하기
class SRCNN(nn.Module):
    def __init__(self):
        super().__init__()

        # padding_mode='replicate'는 zero padding이 아닌, 주변 값을 복사해서 padding 합니다.
        self.conv1 = nn.Conv2d(1, 64, 9, padding=2, padding_mode='replicate')
        self.conv2 = nn.Conv2d(64, 32, 1, padding=2, padding_mode='replicate')
        self.conv3 = nn.Conv2d(32, 1, 5, padding=2, padding_mode='replicate')

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.conv3(x)

        return x

# %%
x = torch.randn(64,1,33,33).to(device)
model = SRCNN().to(device)
output = model(x)

# %%
def initialize_weights(model):
    classname = model.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)

model.apply(initialize_weights);

# %%
# loss
#loss_func = nn.MSELoss()
loss_func = nn.HuberLoss()

# optimizer
import torch.optim as optim
optimizer = optim.Adam(model.parameters())

# PSNR function: 모델의 출력값과 high-resoultion의 유사도를 측정합니다.
# PSNR 값이 클수록 좋습니다.
def psnr(label, outputs, max_val=1.):
    label = label.cpu().detach().numpy()
    outputs = outputs.cpu().detach().numpy()
    img_diff = outputs - label
    rmse = math.sqrt(np.mean((img_diff)**2))
    if rmse == 0: # label과 output이 완전히 일치하는 경우
        return 100
    else:
        psnr = 20 * math.log10(max_val/rmse)
        return psnr

# train 함수
def train(model, data_dl):
    model.train()
    running_loss = 0.0
    running_psnr = 0.0

    for ba, data in enumerate(data_dl):
        image = data[0].to(device)
        label = data[1].to(device)

        optimizer.zero_grad()
        outputs = model(image)
        loss = loss_func(outputs, label)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        batch_psnr = psnr(label, outputs)
        running_psnr += batch_psnr
    
    final_loss = running_loss / len(data_dl.dataset)
    final_psnr = running_psnr / int(len(train_ds)/data_dl.batch_size)
    return final_loss, final_psnr

# validation 함수
def validate(model, data_dl, epoch):
    
    model.eval()
    running_loss = 0.0
    running_psnr = 0.0
    with torch.no_grad():
        for ba, data in enumerate(data_dl):
            image = data[0].to(device)
            label = data[1].to(device)

            outputs = model(image)
            loss = loss_func(outputs, label)

            running_loss += loss.item()
            batch_psnr = psnr(label,outputs)
            running_psnr += batch_psnr

        outputs = outputs.cpu()
        # tensor를 입력받아 이미지 파일로 저장
        save_image(outputs, f'/content/outputs/{epoch}.jpg')
    
    final_loss = running_loss / len(data_dl.dataset)
    final_psnr = running_psnr / int(len(val_ds)/data_dl.batch_size)
    return final_loss, final_psnr

# %%
# 이미지를 저장할 폴더 생성
# !mkdir outputs

# %%
num_epochs = 100

# 학습하기
train_loss, val_loss = [], []
train_psnr, val_psnr = [], []
start = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch + 1} of {num_epochs}')
    train_epoch_loss, train_epoch_psnr = train(model, train_dl)
    val_epoch_loss, val_epoch_psnr = validate(model, val_dl, epoch)

    train_loss.append(train_epoch_loss)
    train_psnr.append(train_epoch_psnr)
    val_loss.append(val_epoch_loss)
    val_psnr.append(val_epoch_psnr)
    end = time.time()
    print(f'Train PSNR: {train_epoch_psnr:.3f}, Val PSNR: {val_epoch_psnr:.3f}, Time: {end-start:.2f} sec')
# Out:
# Epoch 1 of 100
# Train PSNR: 19.910, Val PSNR: 24.071, Time: 2.89 sec
# Epoch 2 of 100
# Train PSNR: 24.922, Val PSNR: 26.068, Time: 4.99 sec
# Epoch 3 of 100
# Train PSNR: 25.991, Val PSNR: 26.493, Time: 7.14 sec
# Epoch 4 of 100
# Train PSNR: 26.297, Val PSNR: 26.789, Time: 9.26 sec
# Epoch 5 of 100
# Train PSNR: 26.598, Val PSNR: 27.094, Time: 11.36 sec
# Epoch 6 of 100
# Train PSNR: 26.864, Val PSNR: 27.319, Time: 13.47 sec
# Epoch 7 of 100
# Train PSNR: 27.068, Val PSNR: 27.522, Time: 15.58 sec
# Epoch 8 of 100
# Train PSNR: 27.201, Val PSNR: 27.577, Time: 17.70 sec
# Epoch 9 of 100
# Train PSNR: 27.235, Val PSNR: 27.601, Time: 19.82 sec
# Epoch 10 of 100
# Train PSNR: 27.255, Val PSNR: 27.617, Time: 21.95 sec
# Epoch 11 of 100
# Train PSNR: 27.267, Val PSNR: 27.604, Time: 24.06 sec
# Epoch 12 of 100
# Train PSNR: 27.275, Val PSNR: 27.598, Time: 26.18 sec
# Epoch 13 of 100
# Train PSNR: 27.285, Val PSNR: 27.598, Time: 28.30 sec
# Epoch 14 of 100
# Train PSNR: 27.289, Val PSNR: 27.635, Time: 30.42 sec
# Epoch 15 of 100
# Train PSNR: 27.290, Val PSNR: 27.656, Time: 32.54 sec
# Epoch 16 of 100
# Train PSNR: 27.307, Val PSNR: 27.674, Time: 34.65 sec
# Epoch 17 of 100
# Train PSNR: 27.307, Val PSNR: 27.678, Time: 36.78 sec
# Epoch 18 of 100
# Train PSNR: 27.306, Val PSNR: 27.673, Time: 38.91 sec
# Epoch 19 of 100
# Train PSNR: 27.300, Val PSNR: 27.688, Time: 41.03 sec
# Epoch 20 of 100
# Train PSNR: 27.315, Val PSNR: 27.690, Time: 43.15 sec
# Epoch 21 of 100
# Train PSNR: 27.307, Val PSNR: 27.700, Time: 45.26 sec
# Epoch 22 of 100
# Train PSNR: 27.318, Val PSNR: 27.705, Time: 47.37 sec
# Epoch 23 of 100
# Train PSNR: 27.312, Val PSNR: 27.707, Time: 49.48 sec
# Epoch 24 of 100
# Train PSNR: 27.324, Val PSNR: 27.713, Time: 51.59 sec
# Epoch 25 of 100
# Train PSNR: 27.316, Val PSNR: 27.716, Time: 53.70 sec
# Epoch 26 of 100
# Train PSNR: 27.321, Val PSNR: 27.681, Time: 55.82 sec
# Epoch 27 of 100
# Train PSNR: 27.332, Val PSNR: 27.704, Time: 57.93 sec
# Epoch 28 of 100
# Train PSNR: 27.331, Val PSNR: 27.548, Time: 60.04 sec
# Epoch 29 of 100
# Train PSNR: 27.338, Val PSNR: 27.715, Time: 62.15 sec
# Epoch 30 of 100
# Train PSNR: 27.333, Val PSNR: 27.730, Time: 64.28 sec
# Epoch 31 of 100
# Train PSNR: 27.334, Val PSNR: 27.734, Time: 66.39 sec
# Epoch 32 of 100
# Train PSNR: 27.341, Val PSNR: 27.735, Time: 68.53 sec
# Epoch 33 of 100
# Train PSNR: 27.344, Val PSNR: 27.728, Time: 70.65 sec
# Epoch 34 of 100
# Train PSNR: 27.352, Val PSNR: 27.293, Time: 72.90 sec
# Epoch 35 of 100
# Train PSNR: 27.339, Val PSNR: 27.750, Time: 75.17 sec
# Epoch 36 of 100
# Train PSNR: 27.367, Val PSNR: 27.653, Time: 77.29 sec
# Epoch 37 of 100
# Train PSNR: 27.344, Val PSNR: 27.751, Time: 79.41 sec
# Epoch 38 of 100
# Train PSNR: 27.373, Val PSNR: 27.425, Time: 81.54 sec
# Epoch 39 of 100
# Train PSNR: 27.365, Val PSNR: 27.767, Time: 83.67 sec
# Epoch 40 of 100
# Train PSNR: 27.382, Val PSNR: 27.537, Time: 85.80 sec
# Epoch 41 of 100
# Train PSNR: 27.372, Val PSNR: 27.562, Time: 87.92 sec
# Epoch 42 of 100
# Train PSNR: 27.386, Val PSNR: 27.420, Time: 90.06 sec
# Epoch 43 of 100
# Train PSNR: 27.375, Val PSNR: 27.782, Time: 92.18 sec
# Epoch 44 of 100
# Train PSNR: 27.398, Val PSNR: 27.793, Time: 94.31 sec
# Epoch 45 of 100
# Train PSNR: 27.393, Val PSNR: 27.344, Time: 96.44 sec
# Epoch 46 of 100
# Train PSNR: 27.388, Val PSNR: 27.801, Time: 98.60 sec
# Epoch 47 of 100
# Train PSNR: 27.427, Val PSNR: 27.554, Time: 100.73 sec
# Epoch 48 of 100
# Train PSNR: 27.409, Val PSNR: 27.730, Time: 102.86 sec
# Epoch 49 of 100
# Train PSNR: 27.410, Val PSNR: 27.455, Time: 105.00 sec
# Epoch 50 of 100
# Train PSNR: 27.420, Val PSNR: 27.816, Time: 107.13 sec
# Epoch 51 of 100
# Train PSNR: 27.432, Val PSNR: 27.433, Time: 109.26 sec
# Epoch 52 of 100
# Train PSNR: 27.439, Val PSNR: 27.835, Time: 111.40 sec
# Epoch 53 of 100
# Train PSNR: 27.454, Val PSNR: 27.482, Time: 113.52 sec
# Epoch 54 of 100
# Train PSNR: 27.454, Val PSNR: 27.843, Time: 115.64 sec
# Epoch 55 of 100
# Train PSNR: 27.468, Val PSNR: 27.866, Time: 117.76 sec
# Epoch 56 of 100
# Train PSNR: 27.471, Val PSNR: 27.851, Time: 119.88 sec
# Epoch 57 of 100
# Train PSNR: 27.471, Val PSNR: 27.840, Time: 121.99 sec
# Epoch 58 of 100
# Train PSNR: 27.484, Val PSNR: 27.463, Time: 124.11 sec
# Epoch 59 of 100
# Train PSNR: 27.483, Val PSNR: 27.878, Time: 126.24 sec
# Epoch 60 of 100
# Train PSNR: 27.498, Val PSNR: 27.885, Time: 128.39 sec
# Epoch 61 of 100
# Train PSNR: 27.499, Val PSNR: 27.905, Time: 130.51 sec
# Epoch 62 of 100
# Train PSNR: 27.504, Val PSNR: 27.912, Time: 132.62 sec
# Epoch 63 of 100
# Train PSNR: 27.510, Val PSNR: 27.918, Time: 134.76 sec
# Epoch 64 of 100
# Train PSNR: 27.516, Val PSNR: 27.926, Time: 136.88 sec
# Epoch 65 of 100
# Train PSNR: 27.522, Val PSNR: 27.927, Time: 139.01 sec
# Epoch 66 of 100
# Train PSNR: 27.527, Val PSNR: 27.939, Time: 141.15 sec
# Epoch 67 of 100
# Train PSNR: 27.535, Val PSNR: 27.920, Time: 143.27 sec
# Epoch 68 of 100
# Train PSNR: 27.553, Val PSNR: 27.829, Time: 145.39 sec
# Epoch 69 of 100
# Train PSNR: 27.535, Val PSNR: 27.689, Time: 147.52 sec
# Epoch 70 of 100
# Train PSNR: 27.517, Val PSNR: 26.964, Time: 149.63 sec
# Epoch 71 of 100
# Train PSNR: 27.557, Val PSNR: 27.975, Time: 151.75 sec
# Epoch 72 of 100
# Train PSNR: 27.594, Val PSNR: 27.922, Time: 153.86 sec
# Epoch 73 of 100
# Train PSNR: 27.571, Val PSNR: 27.730, Time: 155.98 sec
# Epoch 74 of 100
# Train PSNR: 27.588, Val PSNR: 27.443, Time: 158.12 sec
# Epoch 75 of 100
# Train PSNR: 27.558, Val PSNR: 28.007, Time: 160.26 sec
# Epoch 76 of 100
# Train PSNR: 27.620, Val PSNR: 27.809, Time: 162.38 sec
# Epoch 77 of 100
# Train PSNR: 27.591, Val PSNR: 28.017, Time: 164.51 sec
# Epoch 78 of 100
# Train PSNR: 27.611, Val PSNR: 28.020, Time: 166.63 sec
# Epoch 79 of 100
# Train PSNR: 27.541, Val PSNR: 28.031, Time: 168.76 sec
# Epoch 80 of 100
# Train PSNR: 27.665, Val PSNR: 28.049, Time: 170.90 sec
# Epoch 81 of 100
# Train PSNR: 27.572, Val PSNR: 28.054, Time: 173.02 sec
# Epoch 82 of 100
# Train PSNR: 27.622, Val PSNR: 28.058, Time: 175.15 sec
# Epoch 83 of 100
# Train PSNR: 27.600, Val PSNR: 27.880, Time: 177.28 sec
# Epoch 84 of 100
# Train PSNR: 27.684, Val PSNR: 28.036, Time: 179.41 sec
# Epoch 85 of 100
# Train PSNR: 27.635, Val PSNR: 27.976, Time: 181.53 sec
# Epoch 86 of 100
# Train PSNR: 27.637, Val PSNR: 27.632, Time: 183.65 sec
# Epoch 87 of 100
# Train PSNR: 27.658, Val PSNR: 27.854, Time: 185.78 sec
# Epoch 88 of 100
# Train PSNR: 27.656, Val PSNR: 28.088, Time: 187.91 sec
# Epoch 89 of 100
# Train PSNR: 27.630, Val PSNR: 28.100, Time: 190.04 sec
# Epoch 90 of 100
# Train PSNR: 27.681, Val PSNR: 27.908, Time: 192.17 sec
# Epoch 91 of 100
# Train PSNR: 27.684, Val PSNR: 28.075, Time: 194.30 sec
# Epoch 92 of 100
# Train PSNR: 27.658, Val PSNR: 27.663, Time: 196.43 sec
# Epoch 93 of 100
# Train PSNR: 27.649, Val PSNR: 28.063, Time: 198.55 sec
# Epoch 94 of 100
# Train PSNR: 27.713, Val PSNR: 28.082, Time: 200.68 sec
# Epoch 95 of 100
# Train PSNR: 27.689, Val PSNR: 27.939, Time: 202.81 sec
# Epoch 96 of 100
# Train PSNR: 27.649, Val PSNR: 27.723, Time: 204.93 sec
# Epoch 97 of 100
# Train PSNR: 27.690, Val PSNR: 28.096, Time: 207.06 sec
# Epoch 98 of 100
# Train PSNR: 27.699, Val PSNR: 28.154, Time: 209.18 sec
# Epoch 99 of 100
# Train PSNR: 27.672, Val PSNR: 28.133, Time: 211.30 sec
# Epoch 100 of 100
# Train PSNR: 27.712, Val PSNR: 27.837, Time: 213.42 sec

# %%
# loss plots
plt.figure(figsize=(10, 7))
plt.plot(train_loss, color='orange', label='train loss')
plt.plot(val_loss, color='red', label='validataion loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# psnr plots
plt.figure(figsize=(10, 7))
plt.plot(train_psnr, color='green', label='train PSNR dB')
plt.plot(val_psnr, color='blue', label='validataion PSNR dB')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.show()

# %%
# 이미지 꺼내기
for img, label in val_dl:
    img = img[0]
    label = label[0]
    break

# super-resolution
model.eval()
with torch.no_grad():
    img_ = img.unsqueeze(0)
    img_ = img_.to(device)
    output = model(img_)
    output = output.squeeze(0)

# 시각화
plt.figure(figsize=(15,15))
plt.subplot(1,3,1)
plt.imshow(to_pil_image(img))
plt.title('input')
plt.subplot(1,3,2)
plt.imshow(to_pil_image(output))
plt.title('output')
plt.subplot(1,3,3)
plt.imshow(to_pil_image(label))
plt.title('ground_truth')
